# %% [markdown]
# # 📊 Exploración de Datos - Sistema de Detección de Fatiga
#
# Este notebook explora los datos de sensores recolectados de los dispositivos ESP32.
#
# ## Objetivos:
# 1. Cargar y examinar datos de SensorData y ProcessedMetrics
# 2. Análisis estadístico de variables (HR, SpO2, Acelerómetro)
# 3. Visualizaciones de series de tiempo
# 4. Detección de patrones de fatiga
# 5. Análisis de correlaciones
# 6. Identificación de outliers

# %% [markdown]
# ## 1. Configuración del Entorno Django

# %%
import os
import sys
import django

# Agregar el directorio del proyecto al path
sys.path.append(os.path.dirname(os.path.dirname(os.path.abspath('__file__'))))

# Configurar Django
os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'config.settings')
django.setup()

print("✅ Django configurado correctamente")
